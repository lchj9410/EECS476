# %% [markdown]
# # Training in Brax
#
# In [Brax Environments](https://colab.research.google.com/github/google/brax/blob/main/notebooks/environments.ipynb) we learned about creating environments and using them to quickly generate rollouts. We can learn all kinds of fun and useful behaviors on those environments via Brax's built-in training algorithms.
#
# Let's try them out!

# %%
#@title Install Brax and some helper modules
#@markdown ## ⚠️ PLEASE NOTE:
#@markdown This colab runs best using a TPU runtime.  From the Colab menu, choose Runtime > Change Runtime Type, then select **'TPU'** in the dropdown.

from datetime import datetime
import functools
import os

from IPython.display import HTML, clear_output

import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt

try:
  import brax
except ImportError:
  # !pip install git+https://github.com/google/brax.git@main
  clear_output()
  import brax

from brax import envs
from brax import jumpy as jp
from brax.training import ppo, sac
from brax.io import html
from brax.io import model

if 'COLAB_TPU_ADDR' in os.environ:
  from jax.tools import colab_tpu
  colab_tpu.setup_tpu()

# %% [markdown]
# First let's pick an environment to train an agent:

# %%
#@title Preview a Brax environment { run: "auto" }
#@markdown Select the environment to train:

env_name = "humanoid1" #@param ["ant", "humanoid", "fetch", "grasp", "halfcheetah", "ur5e", "reacher", "h1", "inverted_double_pendulum", "humanoid1"]
env_fn = envs.create_fn(env_name=env_name)
env = env_fn()
state = env.reset(rng=jp.random_prngkey(seed=0))

HTML(html.render(env.sys, [state.qp]))
# Out:
# <html>
#   <head>
#     <title>brax visualizer</title>
#     <style>
#       body {
#         margin: 0;
#         padding: 0;
#       }
#       #brax-viewer {
#         margin: 0;
#         padding: 0;
#         height: 480px;
#       }
#     </style>
#   </head>
#   <body>
#     <script type="application/javascript">
#     var system = {"config": {"bodies": [{"name": "pelvis", "colliders": [{"position": {"x": -0.02, "y": 0.0, "z": 0.0}, "rotation": {"x": -90.0, "y": 0.0, "z": 0.0}, "capsule": {"radius": 0.09, "length": 0.32, "end": 0}, "material": {"friction": 1.0, "elasticity": 0.0}}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 6.6161942, "frozen": {"position": {"x": 0.0, "y": 0.0, "z": 0.0}, "rotation": {"x": 0.0, "y": 0.0, "z": 0.0}, "all": false}}, {"name": "right_thigh", "colliders": [{"position": {"y": 0.005, "z": -0.17, "x": 0.0}, "rotation": {"x": -178.31532, "y": 0.0, "z": 0.0}, "capsule": {"radius": 0.06, "length": 0.46014702, "end": 0}, "material": {"friction": 1.0, "elasticity": 0.0}}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 4.751751, "frozen": {"position": {"x": 0.0, "y": 0.0, "z": 0.0}, "rotation": {"x": 0.0, "y": 0.0, "z": 0.0}, "all": false}}, {"name": "right_shin", "colliders": [{"position": {"z": -0.15, "x": 0.0, "y": 0.0}, "rotation": {"x": -180.0, "y": 0.0, "z": 0.0}, "capsule": {"radius": 0.049, "length": 0.398, "end": -1}, "material": {"friction": 1.0, "elasticity": 0.0}}, {"position": {"z": -0.35, "x": 0.0, "y": 0.0}, "capsule": {"radius": 0.075, "length": 0.15, "end": 1}, "material": {"friction": 1.0, "elasticity": 0.0}}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 4.522842, "frozen": {"position": {"x": 0.0, "y": 0.0, "z": 0.0}, "rotation": {"x": 0.0, "y": 0.0, "z": 0.0}, "all": false}}, {"name": "left_thigh", "colliders": [{"position": {"y": -0.005, "z": -0.17, "x": 0.0}, "rotation": {"x": 178.31532, "y": 0.0, "z": 0.0}, "capsule": {"radius": 0.06, "length": 0.46014702, "end": 0}, "material": {"friction": 1.0, "elasticity": 0.0}}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 4.751751, "frozen": {"position": {"x": 0.0, "y": 0.0, "z": 0.0}, "rotation": {"x": 0.0, "y": 0.0, "z": 0.0}, "all": false}}, {"name": "left_shin", "colliders": [{"position": {"z": -0.15, "x": 0.0, "y": 0.0}, "rotation": {"x": -180.0, "y": 0.0, "z": 0.0}, "capsule": {"radius": 0.049, "length": 0.398, "end": -1}, "material": {"friction": 1.0, "elasticity": 0.0}}, {"position": {"z": -0.35, "x": 0.0, "y": 0.0}, "capsule": {"radius": 0.075, "length": 0.15, "end": 1}, "material": {"friction": 1.0, "elasticity": 0.0}}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 4.522842, "frozen": {"position": {"x": 0.0, "y": 0.0, "z": 0.0}, "rotation": {"x": 0.0, "y": 0.0, "z": 0.0}, "all": false}}, {"name": "floor", "colliders": [{"plane": {}, "material": {"friction": 1.0, "elasticity": 0.0}}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 1.0, "frozen": {"position": {"x": 1.0, "y": 1.0, "z": 1.0}, "rotation": {"x": 1.0, "y": 1.0, "z": 1.0}, "all": true}}], "joints": [{"name": "right_hip_x", "stiffness": 27000.0, "parent": "pelvis", "child": "right_thigh", "parentOffset": {"y": -0.1, "z": -0.04, "x": 0.0}, "childOffset": {"x": 0.0, "y": 0.0, "z": 0.0}, "rotation": {"x": 0.0, "y": 0.0, "z": 0.0}, "angularDamping": 30.0, "angleLimit": [{"min": -10.0, "max": 10.0}, {"min": -30.0, "max": 70.0}, {"min": -10.0, "max": 10.0}], "limitStrength": 2500.0, "springDamping": 80.0}, {"name": "right_knee", "stiffness": 27000.0, "parent": "right_thigh", "child": "right_shin", "parentOffset": {"y": 0.01, "z": -0.383, "x": 0.0}, "childOffset": {"z": 0.02, "x": 0.0, "y": 0.0}, "rotation": {"z": -90.0, "x": 0.0, "y": 0.0}, "angularDamping": 30.0, "angleLimit": [{"min": -160.0, "max": -2.0}], "limitStrength": 2500.0, "springDamping": 80.0}, {"name": "left_hip_x", "stiffness": 27000.0, "parent": "pelvis", "child": "left_thigh", "parentOffset": {"y": 0.1, "z": -0.04, "x": 0.0}, "childOffset": {"x": 0.0, "y": 0.0, "z": 0.0}, "angularDamping": 30.0, "angleLimit": [{"min": -10.0, "max": 10.0}, {"min": -30.0, "max": 70.0}, {"min": -10.0, "max": 10.0}], "limitStrength": 2500.0, "springDamping": 80.0}, {"name": "left_knee", "stiffness": 27000.0, "parent": "left_thigh", "child": "left_shin", "parentOffset": {"y": -0.01, "z": -0.383, "x": 0.0}, "child ...
#     </script>
#     <div id="brax-viewer"></div>
#     <script type="module">
#       import {Viewer} from 'https://cdn.jsdelivr.net/gh/google/brax@v0.0.10/js/viewer.js';
#       const domElement = document.getElementById('brax-viewer');
#       var viewer = new Viewer(domElement, system);
#     </script>
#   </body>
# </html>

# %% [markdown]
# # Training
#
# Brax provides out of the box the following training algorithms:
#
# * [Proximal policy optimization](https://github.com/google/brax/blob/main/brax/training/ppo.py)
# * [Soft actor-critic](https://github.com/google/brax/blob/main/brax/training/sac.py)
# * [Evolutionary strategy](https://github.com/google/brax/blob/main/brax/training/es.py)
# * [Analytic policy gradients](https://github.com/google/brax/blob/main/brax/training/apg.py)
# * [Augmented random search](https://github.com/google/brax/blob/main/brax/training/ars.py)
#
# Trainers take as input an environment function and some hyperparameters, and return an inference function to operate the environment.

# %%
#@title Training some pre-included Brax environments

# We determined some reasonable hyperparameters offline and share them here.
train_fn = {
  'ant': functools.partial(
      ppo.train, num_timesteps = 30000000, log_frequency = 20,
      reward_scaling = 10, episode_length = 1000, normalize_observations = True,
      action_repeat = 1, unroll_length = 5, num_minibatches = 32,
      num_update_epochs = 4, discounting = 0.97, learning_rate = 3e-4,
      entropy_cost = 1e-2, num_envs = 2048, batch_size = 1024
  ),
  'humanoid1': functools.partial(
      ppo.train, num_timesteps = 100000000, log_frequency = 20,
      reward_scaling = 0.1, episode_length = 1000, normalize_observations = True,
      action_repeat = 1, unroll_length = 10, num_minibatches = 32,
      num_update_epochs = 8, discounting = 0.97, learning_rate = 3e-4,
      entropy_cost = 1e-3, num_envs = 2048, batch_size = 1024, seed=1
  ),
  'fetch': functools.partial(
      ppo.train, num_timesteps = 100_000_000, log_frequency = 20,
      reward_scaling = 5, episode_length = 1000, normalize_observations = True,
      action_repeat = 1, unroll_length = 20, num_minibatches = 32,
      num_update_epochs = 4, discounting = 0.997, learning_rate = 3e-4,
      entropy_cost = 0.001, num_envs = 2048, batch_size = 256
  ),
  'grasp': functools.partial(
      ppo.train, num_timesteps = 600_000_000, log_frequency = 10,
      reward_scaling = 10, episode_length = 1000, normalize_observations = True,
      action_repeat = 1, unroll_length = 20, num_minibatches = 32,
      num_update_epochs = 2, discounting = 0.99, learning_rate = 3e-4,
      entropy_cost = 0.001, num_envs = 2048, batch_size = 256
  ),
  'halfcheetah': functools.partial(
      ppo.train, num_timesteps = 100_000_000, log_frequency = 10,
      reward_scaling = 1, episode_length = 1000, normalize_observations = True,
      action_repeat = 1, unroll_length = 20, num_minibatches = 32,
      num_update_epochs = 8, discounting = 0.95, learning_rate = 3e-4,
      entropy_cost = 0.001, num_envs = 2048, batch_size = 512
  ),
  'ur5e': functools.partial(
      ppo.train, num_timesteps = 20_000_000, log_frequency = 20,
      reward_scaling = 10, episode_length = 1000, normalize_observations = True,
      action_repeat = 1, unroll_length = 5, num_minibatches = 32,
      num_update_epochs = 4, discounting = 0.95, learning_rate = 2e-4,
      entropy_cost = 1e-2, num_envs = 2048, batch_size = 1024,
      max_devices_per_host = 8
  ),
  'reacher': functools.partial(
      ppo.train, num_timesteps = 100_000_000, log_frequency = 20,
      reward_scaling = 5, episode_length = 1000, normalize_observations = True,
      action_repeat = 4, unroll_length = 50, num_minibatches = 32,
      num_update_epochs = 8, discounting = 0.95, learning_rate = 3e-4,
      entropy_cost = 1e-3, num_envs = 2048, batch_size = 256,
      max_devices_per_host = 8, seed = 1),
}[env_name]
max_y = {'ant': 6000, 
         'humanoid1': 12000, 
         'fetch': 15, 
         'grasp': 100, 
         'halfcheetah': 8000,
         'ur5e': 10,
         'reacher': 5}[env_name]

min_y = {'reacher': -100}.get(env_name, 0)

xdata = []
ydata = []
times = [datetime.now()]

def progress(num_steps, metrics):
  times.append(datetime.now())
  xdata.append(num_steps)
  ydata.append(metrics['eval/episode_reward'])
  clear_output(wait=True)
  plt.xlim([0, train_fn.keywords['num_timesteps']])
  plt.ylim([min_y, max_y])
  plt.xlabel('# environment steps')
  plt.ylabel('reward per episode')
  plt.plot(xdata, ydata)
  plt.show()

inference_fn, params, _ = train_fn(environment_fn=env_fn, progress_fn=progress)

print(f'time to jit: {times[1] - times[0]}')
print(f'time to train: {times[-1] - times[1]}')
# Out:
# time to jit: 0:01:04.587137
# time to train: 0:03:05.965315

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-12-d5df0069828e> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     111       timeout_ms=timeout_ms,
#     112       use_metadata_server=use_metadata_server,
# --> 113       ephemeral=ephemeral)
#     114
#     115
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, use_metadata_server, ephemeral)
#     134   if ephemeral:
#     135     _message.blocking_request(
# --> 136         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     137
#     138   mountpoint = _os.path.expanduser(mountpoint)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     173   request_id = send_request(
#     174       request_type, request, parent=parent, expect_reply=True)
# --> 175   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: Error: credential propagation was unsuccessful

# %% [markdown]
# The trainers return an inference function, parameters, and the final set of metrics gathered during evaluation.
#
# # Saving and Loading Policies
#
# Brax can save and load trained policies:

# %%
model.save_params('/tmp/params', params)
inference_fn = ppo.make_inference_fn(
    env.observation_size, env.action_size, True)
params = model.load_params('/tmp/params')

# %% [markdown]
# # Visualizing a Policy's Behavior
#
# We can use the policy to generate a rollout for visualization:

# %%
#@title Visualizing a trajectory of the learned inference function

jit_env_reset = jax.jit(env.reset)
jit_env_step = jax.jit(env.step)
jit_inference_fn = jax.jit(inference_fn)

rollout = []
rng = jax.random.PRNGKey(seed=0)
state = jit_env_reset(rng=rng)
while not state.done:
  rollout.append(state)
  act_rng, rng = jax.random.split(rng)
  act = jit_inference_fn(params, state.obs, act_rng)
  state = jit_env_step(state, act)

HTML(html.render(env.sys, [s.qp for s in rollout]))
# Out:
# <html>
#   <head>
#     <title>brax visualizer</title>
#     <style>
#       body {
#         margin: 0;
#         padding: 0;
#       }
#       #brax-viewer {
#         margin: 0;
#         padding: 0;
#         height: 480px;
#       }
#     </style>
#   </head>
#   <body>
#     <script type="application/javascript">
#     var system = {"config": {"bodies": [{"name": "pelvis", "colliders": [{"position": {"x": -0.02, "y": 0.0, "z": 0.0}, "rotation": {"x": -90.0, "y": 0.0, "z": 0.0}, "capsule": {"radius": 0.09, "length": 0.32, "end": 0}, "material": {"friction": 1.0, "elasticity": 0.0}}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 6.6161942, "frozen": {"position": {"x": 0.0, "y": 0.0, "z": 0.0}, "rotation": {"x": 0.0, "y": 0.0, "z": 0.0}, "all": false}}, {"name": "right_thigh", "colliders": [{"position": {"y": 0.005, "z": -0.17, "x": 0.0}, "rotation": {"x": -178.31532, "y": 0.0, "z": 0.0}, "capsule": {"radius": 0.06, "length": 0.46014702, "end": 0}, "material": {"friction": 1.0, "elasticity": 0.0}}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 4.751751, "frozen": {"position": {"x": 0.0, "y": 0.0, "z": 0.0}, "rotation": {"x": 0.0, "y": 0.0, "z": 0.0}, "all": false}}, {"name": "right_shin", "colliders": [{"position": {"z": -0.15, "x": 0.0, "y": 0.0}, "rotation": {"x": -180.0, "y": 0.0, "z": 0.0}, "capsule": {"radius": 0.049, "length": 0.398, "end": -1}, "material": {"friction": 1.0, "elasticity": 0.0}}, {"position": {"z": -0.35, "x": 0.0, "y": 0.0}, "capsule": {"radius": 0.075, "length": 0.15, "end": 1}, "material": {"friction": 1.0, "elasticity": 0.0}}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 4.522842, "frozen": {"position": {"x": 0.0, "y": 0.0, "z": 0.0}, "rotation": {"x": 0.0, "y": 0.0, "z": 0.0}, "all": false}}, {"name": "left_thigh", "colliders": [{"position": {"y": -0.005, "z": -0.17, "x": 0.0}, "rotation": {"x": 178.31532, "y": 0.0, "z": 0.0}, "capsule": {"radius": 0.06, "length": 0.46014702, "end": 0}, "material": {"friction": 1.0, "elasticity": 0.0}}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 4.751751, "frozen": {"position": {"x": 0.0, "y": 0.0, "z": 0.0}, "rotation": {"x": 0.0, "y": 0.0, "z": 0.0}, "all": false}}, {"name": "left_shin", "colliders": [{"position": {"z": -0.15, "x": 0.0, "y": 0.0}, "rotation": {"x": -180.0, "y": 0.0, "z": 0.0}, "capsule": {"radius": 0.049, "length": 0.398, "end": -1}, "material": {"friction": 1.0, "elasticity": 0.0}}, {"position": {"z": -0.35, "x": 0.0, "y": 0.0}, "capsule": {"radius": 0.075, "length": 0.15, "end": 1}, "material": {"friction": 1.0, "elasticity": 0.0}}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 4.522842, "frozen": {"position": {"x": 0.0, "y": 0.0, "z": 0.0}, "rotation": {"x": 0.0, "y": 0.0, "z": 0.0}, "all": false}}, {"name": "floor", "colliders": [{"plane": {}, "material": {"friction": 1.0, "elasticity": 0.0}}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 1.0, "frozen": {"position": {"x": 1.0, "y": 1.0, "z": 1.0}, "rotation": {"x": 1.0, "y": 1.0, "z": 1.0}, "all": true}}], "joints": [{"name": "right_hip_x", "stiffness": 27000.0, "parent": "pelvis", "child": "right_thigh", "parentOffset": {"y": -0.1, "z": -0.04, "x": 0.0}, "childOffset": {"x": 0.0, "y": 0.0, "z": 0.0}, "rotation": {"x": 0.0, "y": 0.0, "z": 0.0}, "angularDamping": 30.0, "angleLimit": [{"min": -10.0, "max": 10.0}, {"min": -30.0, "max": 70.0}, {"min": -10.0, "max": 10.0}], "limitStrength": 2500.0, "springDamping": 80.0}, {"name": "right_knee", "stiffness": 27000.0, "parent": "right_thigh", "child": "right_shin", "parentOffset": {"y": 0.01, "z": -0.383, "x": 0.0}, "childOffset": {"z": 0.02, "x": 0.0, "y": 0.0}, "rotation": {"z": -90.0, "x": 0.0, "y": 0.0}, "angularDamping": 30.0, "angleLimit": [{"min": -160.0, "max": -2.0}], "limitStrength": 2500.0, "springDamping": 80.0}, {"name": "left_hip_x", "stiffness": 27000.0, "parent": "pelvis", "child": "left_thigh", "parentOffset": {"y": 0.1, "z": -0.04, "x": 0.0}, "childOffset": {"x": 0.0, "y": 0.0, "z": 0.0}, "angularDamping": 30.0, "angleLimit": [{"min": -10.0, "max": 10.0}, {"min": -30.0, "max": 70.0}, {"min": -10.0, "max": 10.0}], "limitStrength": 2500.0, "springDamping": 80.0}, {"name": "left_knee", "stiffness": 27000.0, "parent": "left_thigh", "child": "left_shin", "parentOffset": {"y": -0.01, "z": -0.383, "x": 0.0}, "child ...

# %% [markdown]
# ವಿದಾಯ! 👋

# %%
from google.colab import files

# %%
# !zip -r /home/colab_brax_env.zip /usr/local/lib/python3.7/dist-packages/brax/envs
# Out:
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/ (stored 0%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/hopper.py (deflated 67%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/to_torch.py (deflated 58%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/ (stored 0%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/humanoid1.cpython-37.pyc (deflated 61%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/fast.cpython-37.pyc (deflated 42%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/fetch.cpython-37.pyc (deflated 69%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/hopper.cpython-37.pyc (deflated 55%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/ur5e.cpython-37.pyc (deflated 62%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/inverted_double_pendulum.cpython-37.pyc (deflated 50%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/inverted_pendulum.cpython-37.pyc (deflated 45%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/humanoid.cpython-37.pyc (deflated 71%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/walker2d.cpython-37.pyc (deflated 63%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/humanoid_standup.cpython-37.pyc (deflated 72%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/reacher.cpython-37.pyc (deflated 53%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/halfcheetah.cpython-37.pyc (deflated 67%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/ant.cpython-37.pyc (deflated 69%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/reacherangle.cpython-37.pyc (deflated 53%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/env.cpython-37.pyc (deflated 53%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/to_torch.cpython-37.pyc (deflated 54%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/wrappers.cpython-37.pyc (deflated 59%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/grasp.cpython-37.pyc (deflated 71%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/__init__.cpython-37.pyc (deflated 45%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__pycache__/swimmer.cpython-37.pyc (deflated 52%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/grasp.py (deflated 79%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/env.py (deflated 60%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/.ipynb_checkpoints/ (stored 0%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/inverted_double_pendulum.py (deflated 61%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/fetch.py (deflated 77%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/inverted_pendulum.py (deflated 54%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/fast.py (deflated 49%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/reacherangle.py (deflated 63%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/wrappers.py (deflated 75%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/swimmer.py (deflated 64%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/reacher.py (deflated 63%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/walker2d.py (deflated 72%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/ur5e.py (deflated 71%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/__init__.py (deflated 65%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/ant.py (deflated 74%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/halfcheetah.py (deflated 71%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/humanoid1.py (deflated 71%)
#   adding: usr/local/lib/python3.7/dist-packages/brax/envs/humanoid_standup.py (deflated 78%)

# %%
files.download('/home/colab_brax_env.zip')
